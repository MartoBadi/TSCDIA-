# %% [markdown]
# # Ejercicio 1: Analizador de Texto
#
# Este proyecto tiene como objetivo aplicar los conceptos aprendidos sobre strings, input, indexación y formateo de strings en Python. El programa permitirá al usuario ingresar un texto y luego elegir realizar diversas operaciones de análisis sobre ese texto.
#
# ## Consigna
# Vas a crear un programa que le pida al usuario que ingrese un texto de al menos 10 palabras. Tu programa va a procesar ese texto y le va a devolver un análisis detallado, que incluya:
# 1. Contar el número total de caracteres en el texto
# 2. Contar el número de caracteres sin incluir los espacios
# 3. Contar la cantidad de vocales que hay en el texto
# 4. Contar el número total de palabras en el texto ingresado
#
# **nota**: para resolver los siguientes items, deberás investigar otros métodos de strings que no hemos visto. Recuerda utilizar *type*, *dir* y *help*
#
# 5. Eliminar la primera palabra
# 6. Reemplazar todos los espacios por guiones medios (-)
# 8. Cambia las mayúsculas a minúsculas y las minúsculas a mayúsculas
#
# Al finalizar el procesamiento, se imprimirán 8 cadenas literales mostrando los resultados del análisis (una cadena por cada resultado).
# <br>
# <br>
# <br>

# %% [markdown]
# ### Resolución
#
# Ingreso del usuario:

# %% [markdown]
# 1. Contar el número total de caracteres en el texto

# %%
texto = "Hola"

texto.count("") - 1
# Out:
# 4

# %% [markdown]
# 2. Contar el número de caracteres sin incluir los espacios

# %%
texto = "Hola, ¿qué tal?"

texto.count("") - texto.count(" ") - 1
# Out:
# 13

# %% [markdown]
# 3. Contar la cantidad de vocales que hay en el texto

# %%
texto = "Hola"

texto.count("a") + texto.count("e") + texto.count("i") + texto.count("o") + texto.count("u")
# Out:
# 2

# %% [markdown]
# 4. Contar el número total de palabras en el texto ingresado

# %%
texto = " Hola, ¿qué tal?"

texto.strip().count(" ") + 1
# Out:
# 3

# %% [markdown]
# 5. Eliminar la primera palabra

# %%
texto = "Holo"

texto.replace("o", "a")
# Out:
# 'Hala'

# %%
texto = "Hola, ¿qué tal?"

texto.partition(" ")[-1]
# Out:
# '¿qué tal?'

# %% [markdown]
# 6. Reemplazar todos los espacios por guiones medios (-)

# %%
texto = "Hola, ¿qué tal?"

texto.replace(" ", "-")
# Out:
# 'Hola,-¿qué-tal?'

# %% [markdown]
# 7. Cambia las mayúsculas a minúsculas y las minúsculas a mayúsculas

# %%
texto = "Hola"

texto.swapcase()
# Out:
# 'hOLA'

# %% [markdown]
# Mostrar al usuario los resultados del análisis de su texto.
