# %% [markdown]
# # Clase del 09 de Abril

# %%
input()
# Out:
#  Hola
# 'Hola'

# %%
nombre = input("Ingrese su nombre: ")
# Out:
# Ingrese su nombre:  Miguel

# %%
nombre
# Out:
# 'Miguel'

# %%
print("Hola " + nombre + "!")
# Out:
# Hola Miguel!

# %%
edad = input("Ingrese su edad: ")
# Out:
# Ingrese su edad:  37

# %%
type(edad)
# Out:
# str

# %%
edad = int(input("Ingrese su edad: "))
# Out:
# Ingrese su edad:  37

# %%
type(edad)
# Out:
# int

# %%
saludo = "Hola"
nombre = "Miguel"

saludo + " " + nombre
# Out:
# 'Hola Miguel'

# %%
saludo = "Hola"
nombre = "Miguel"
edad = 37 # este valor es un entero, debe convertirse a string para poder concatenarse

saludo + " " + nombre + " tenes " + str(edad) + " años"
# Out:
# 'Hola Miguel tenes 37 años'

# %% [markdown]
# ## Concateno con "format"

# %%
frase = "Hola {}, tenes {} años".format(nombre, edad)

frase
# Out:
# 'Hola Miguel, tenes 37 años'

# %% [markdown]
# ## Concateno con "f-string"

# %%
frase_2 = f"Hola {nombre}, tenes {edad} años"

frase_2
# Out:
# 'Hola Miguel, tenes 37 años'

# %% [markdown]
# # Listas

# %%
frutas = []

# %%
type(frutas)
# Out:
# list

# %%
frutas = ["manzana", "durazno", "banana"]

# %%
type(frutas)
# Out:
# list

# %%
lista_numeros = [70, 65, 87]

# %%
type(lista_numeros)
# Out:
# list

# %%
lista_de_listas = [[1, 2, 3], ["hola", "como", "estan"], ["a", "b", "c"]]

# %%
type(lista_de_listas)
# Out:
# list

# %%
mala_practica = [4, 2.3, "string"]

# %%
type(mala_practica)
# Out:
# list

# %%
frutas
# Out:
# ['manzana', 'durazno', 'banana']

# %%
frutas[0]
# Out:
# 'manzana'

# %%
frutas[1]
# Out:
# 'durazno'

# %%
lista_de_listas
# Out:
# [[1, 2, 3], ['hola', 'como', 'estan'], ['a', 'b', 'c']]

# %%
lista_de_listas[1]
# Out:
# ['hola', 'como', 'estan']

# %%
lista_de_listas[1][2]
# Out:
# 'estan'

# %%
frutas
# Out:
# ['manzana', 'durazno', 'banana']

# %%
frutas.append("sandia")

frutas
# Out:
# ['manzana', 'durazno', 'banana', 'sandia']

# %%
frutas.sort()

frutas
# Out:
# ['banana', 'durazno', 'manzana', 'sandia']

# %%
frutas.sort(reverse = True)

frutas
# Out:
# ['sandia', 'manzana', 'durazno', 'banana']

# %%
frutas.remove("durazno")

frutas
# Out:
# ['sandia', 'manzana', 'banana']

# %%
frutas.remove("pera")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 frutas.remove("pera")
#
# ValueError: list.remove(x): x not in list

# %%
frutas
# Out:
# ['sandia', 'manzana', 'banana']

# %%
frutas.reverse()

frutas
# Out:
# ['banana', 'manzana', 'sandia']

# %%
len(frutas)
# Out:
# 3

# %% [markdown]
# ## Concateno Listas

# %%
lista_1 = [4, 5, 6]
lista_2 = [8, 9, 10]

concateno = lista_1 + lista_2

# %%
concateno
# Out:
# [4, 5, 6, 8, 9, 10]

# %%
type(concateno)
# Out:
# list

# %%
multiplicar = lista_1 * 4

# %%
multiplicar
# Out:
# [4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6]

# %%
segmentada = multiplicar[1:4]

segmentada
# Out:
# [5, 6, 4]

# %%
segmentada = multiplicar[:6]

segmentada
# Out:
# [4, 5, 6, 4, 5, 6]

# %%
segmentada = multiplicar[:]

segmentada
# Out:
# [4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6]

# %% [markdown]
# # Tuplas

# %%
tupla = 1, 2

# %%
type(tupla)
# Out:
# tuple

# %%
tupla_2 = (1, 2)

# %%
type(tupla_2)
# Out:
# tuple

# %%
cliente = ("Miguel", "Perez", 45)

# %%
type(cliente)
# Out:
# tuple

# %%
cliente
# Out:
# ('Miguel', 'Perez', 45)

# %%
tupla_numeros = (1, 2, 5, 9, 57)

# %%
tupla_numeros[3]
# Out:
# 9

# %%
tupla_numeros[1:3]
# Out:
# (2, 5)

# %%
tupla_numeros
# Out:
# (1, 2, 5, 9, 57)

# %%
tupla_numeros[2] = 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 tupla_numeros[2] = 8
#
# TypeError: 'tuple' object does not support item assignment

# %%
tupla_numeros_2 = (1, 2, 2, 2, 5, 5, 7)

# %%
tupla_numeros_2.count(1)
# Out:
# 1

# %%
tupla_numeros_2.count(2)
# Out:
# 3

# %%
tupla_numeros_2.count(5)
# Out:
# 2

# %%
tupla_numeros_2.index(5)
# Out:
# 4

# %%
tupla_numeros_2.index(2)
# Out:
# 1

# %% [markdown]
# ## Desempaquetado

# %%
auto = ("Peugeot", 2008, "Rojo", 2023, 5)

# %%
auto
# Out:
# ('Peugeot', 2008, 'Rojo', 2023, 5)

# %%
(Marca, Tipo, Color, Modelo, Puertas) = auto

# %%
auto
# Out:
# ('Peugeot', 2008, 'Rojo', 2023, 5)

# %%
Tipo, Modelo
# Out:
# (2008, 2023)

# %%
Marca, Puertas
# Out:
# ('Peugeot', 5)

# %%
Color
# Out:
# 'Rojo'

# %%
nombre = ("Martin", "Gonzalez")
nacimiento = (1986, 10, 2)

# %%
cliente = (nombre, nacimiento)

# %%
cliente
# Out:
# (('Martin', 'Gonzalez'), (1986, 10, 2))

# %%
cliente[0]
# Out:
# ('Martin', 'Gonzalez')

# %%
cliente[1][0]
# Out:
# 1986

# %% [markdown]
# # Diccionarios

# %%
dic = {}

# %%
type(dic)
# Out:
# dict

# %%
edades = {"Juan": 30, "María": 51}

# %%
edades
# Out:
# {'Juan': 30, 'María': 51}

# %%
type(edades)
# Out:
# dict

# %%
edades[1]  # esto NO puede hacerse con los diccionarios
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 edades[1]
#
# KeyError: 1

# %%
edades["Juan"]
# Out:
# 30

# %%
dir(edades)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
edades
# Out:
# {'Juan': 30, 'María': 51}

# %%
edades["Ana"] = 39

# %%
edades
# Out:
# {'Juan': 30, 'María': 51, 'Ana': 39}

# %%
edades.keys()
# Out:
# dict_keys(['Juan', 'María', 'Ana'])

# %%
edades.values()
# Out:
# dict_values([30, 51, 39])

# %%
edades.get("Juan")
# Out:
# 30

# %%
edades["Juan"]
# Out:
# 30

# %%
edades.items()
# Out:
# dict_items([('Juan', 30), ('María', 51), ('Ana', 39)])

# %%
edades
# Out:
# {'Juan': 30, 'María': 51, 'Ana': 39}

# %%
edades["Juan"] = 45

# %%
edades
# Out:
# {'Juan': 45, 'María': 51, 'Ana': 39}

# %%
edades.update({"Juan":42})

# %%
edades
# Out:
# {'Juan': 42, 'María': 51, 'Ana': 39}
