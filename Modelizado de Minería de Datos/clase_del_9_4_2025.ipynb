# %% [markdown]
# # Modelizado de Minería de Datos

# %% [markdown]
# ## Modelizado de Minería de Datos

# %% [markdown]
# ### Modelizado de Minería de Datos

# %% [markdown]
# Modelizado de Minería de Datos

# %%
Modelizado de Minería de Datos
# Out:
#   Cell In[244], line 1
#     Modelizado de Minería de Datos
#                ^
# SyntaxError: invalid syntax

# %%
print("Modelizado de Minería de Datos")
# Out:
# Modelizado de Minería de Datos

# %%
1
# Out:
# 1

# %%
10
# Out:
# 10

# %%
miNumero = 1

# %%
miNumero
# Out:
# 1

# %%
10 + 10
# Out:
# 20

# %%
miNumero + 5
# Out:
# 6

# %%
miNumero + miNumero
# Out:
# 2

# %%
otroNumero = 9

# %%
miNumero + otroNumero
# Out:
# 10

# %%
Modelizado de Minería de Datos
# Out:
#   Cell In[246], line 1
#     Modelizado de Minería de Datos
#                ^
# SyntaxError: invalid syntax

# %%
"Modelizado de Minería de Datos"
# Out:
# 'Modelizado de Minería de Datos'

# %%
'Modelizado de Minería de Datos'
# Out:
# 'Modelizado de Minería de Datos'

# %%
"Clase del 08 de Abril de 'Modelizado de Minería de Datos'"
# Out:
# "Clase del 08 de Abril de 'Modelizado de Minería de Datos'"

# %%
'Clase del 08 de Abril de "Modelizado de Minería de Datos"'
# Out:
# 'Clase del 08 de Abril de "Modelizado de Minería de Datos"'

# %%
clase_abril = "Clase del 08 de Abril de 'Modelizado de Minería de Datos'"

# %%
clase_abril
# Out:
# "Clase del 08 de Abril de 'Modelizado de Minería de Datos'"

# %%
print(clase_abril)
# Out:
# Clase del 08 de Abril de 'Modelizado de Minería de Datos'

# %%
8 == 8
# Out:
# True

# %%
clase_abril_2 = 'Clase del 08 de Abril de "Modelizado de Minería de Datos"'

# %%
clase_abril == clase_abril_2
# Out:
# False

# %%
materia = "Minería de Datos"

materia_2 = 'Minería de Datos'

materia == materia_2
# Out:
# True

# %%
a = 3

b = '3'

# %%
a
# Out:
# 3

# %%
b
# Out:
# '3'

# %%
print(b)
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(80)
# Out:
# int

# %%
type(-6)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
pi = 3.14

# %%
type(pi)
# Out:
# float

# %%
type(0.00000032)
# Out:
# float

# %%
type(5 + 7J)
# Out:
# complex

# %%
type(-8 -6J)
# Out:
# complex

# %%
5 + 7J
# Out:
# (5+7j)

# %%
8 -6J
# Out:
# (8-6j)

# %%
-8 + 6J
# Out:
# (-8+6j)

# %%
complex(4, 1)
# Out:
# (4+1j)

# %%
a = complex(-6, 9)

# %%
a
# Out:
# (-6+9j)

# %%
type(a)
# Out:
# complex

# %% [markdown]
# # Operaciones Matemáticas

# %% [markdown]
# ## Suma

# %%
3 + 6
# Out:
# 9

# %% [markdown]
# ## Resta

# %%
9 - 1
# Out:
# 8

# %% [markdown]
# ## Multiplicación

# %%
2 * 5
# Out:
# 10

# %% [markdown]
# ## División

# %%
10 / 3
# Out:
# 3.3333333333333335

# %% [markdown]
# ## División al Piso

# %%
10 // 3
# Out:
# 3

# %% [markdown]
# ## Módulo (Resto de la división)

# %%
10 % 3
# Out:
# 1

# %% [markdown]
# ## Potencia

# %%
4 ** 2
# Out:
# 16

# %% [markdown]
# ## Raíz Cuadrada

# %%
25 ** 0.5
# Out:
# 5.0

# %%
25 ** (1/2)
# Out:
# 5.0

# %% [markdown]
# ## Raíz Cúbica

# %%
25 ** (1/3)
# Out:
# 2.924017738212866

# %% [markdown]
# ## Números Complejos

# %%
a = 1 + 8J
b = 2 + 4J

# %%
a + b
# Out:
# (3+12j)

# %%
a - b
# Out:
# (-1+4j)

# %% [markdown]
# # Operaciones con strings

# %%
numero = "5"

# %%
numero
# Out:
# '5'

# %%
numero + numero
# Out:
# '55'

# %%
"hola" + "alumnos"
# Out:
# 'holaalumnos'

# %%
"hola" + " alumnos"
# Out:
# 'hola alumnos'

# %%
"hola" + " " + "alumnos"
# Out:
# 'hola alumnos'

# %%
2 + int(numero)
# Out:
# 7

# %%
palabra = "manzana"

# %%
palabra
# Out:
# 'manzana'

# %%
type(palabra) # FUNCIÓN MUY ÚTIL
# Out:
# str

# %%
palabra.upper()
# Out:
# 'MANZANA'

# %%
palabra
# Out:
# 'manzana'

# %%
palabra_mayus = palabra.upper()

# %%
palabra
# Out:
# 'manzana'

# %%
palabra_mayus
# Out:
# 'MANZANA'

# %%
palabra.capitalize()
# Out:
# 'Manzana'

# %%
palabra
# Out:
# 'manzana'

# %%
palabra = "ciruela"

# %%
palabra
# Out:
# 'ciruela'

# %%
palabra = palabra.capitalize()

# %%
palabra
# Out:
# 'Ciruela'

# %%
dir(palabra) # FUNCIÓN MUY ÚTIL
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
palabra
# Out:
# 'Ciruela'

# %%
palabra = palabra.lower()

# %%
palabra
# Out:
# 'ciruela'

# %%
help(palabra.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
help(palabra.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
palabra
# Out:
# 'ciruela'

# %%
palabra[0] # Recorremos el string caracter por caracter según el valor entre corchetes, comenzando de izquiera a derecha
# Out:
# 'c'

# %%
palabra[1]
# Out:
# 'i'

# %%
palabra[-1] # Recorremos el string caracter por caracter según el ÚLTIMO caracter, comenzando de derecha a izquierda
# Out:
# 'a'

# %%
palabra[-2]
# Out:
# 'l'

# %%
palabra
# Out:
# 'ciruela'

# %%
palabra[0:4] # El último valor del corchete NO es inclusivo
# Out:
# 'ciru'

# %%
palabra[4:6]
# Out:
# 'el'

# %%
palabra[4:7]
# Out:
# 'ela'

# %%
palabra[4:48]
# Out:
# 'ela'

# %%
palabra[:4]
# Out:
# 'ciru'

# %%
palabra[4:]
# Out:
# 'ela'

# %%
palabra[4:-1]
# Out:
# 'el'

# %%
palabra[:]
# Out:
# 'ciruela'

# %%
palabra[::2]
# Out:
# 'crea'

# %%
palabra[::3]
# Out:
# 'cua'

# %%
palabra[0:4:2]
# Out:
# 'cr'

# %%
palabra[0:4].upper()
# Out:
# 'CIRU'

# %%
palabra
# Out:
# 'ciruela'

# %%
palabra = 'banana'

# %%
palabra
# Out:
# 'banana'

# %%
palabra.count('a')
# Out:
# 3

# %%
espacios = "Puedo contar la cantidad de espacios que hay en una frase"

# %%
espacios.count(" ")
# Out:
# 10

# %%
palabras = "Puedo contar la cantidad de palabras que hay en una frase"

# %%
print(palabras.count(" ") + 1)
# Out:
# 11

# %%
palabras = " Puedo contar la cantidad de palabras que hay en una frase "

# %%
print(palabras.count(" ") + 1)
# Out:
# 13

# %%
print(palabras.strip().count(" ") + 1)
# Out:
# 11

# %% [markdown]
# # Clase del 09 de Abril

# %%
input()
# Out:
#  Hola
# 'Hola'

# %%
nombre = input("Ingrese su nombre: ")
# Out:
# Ingrese su nombre:  Miguel

# %%
nombre
# Out:
# 'Miguel'

# %%
print("Hola " + nombre + "!")
# Out:
# Hola Miguel!

# %%
edad = input("Ingrese su edad: ")
# Out:
# Ingrese su edad:  37

# %%
type(edad)
# Out:
# str

# %%
edad = int(input("Ingrese su edad: "))
# Out:
# Ingrese su edad:  37

# %%
type(edad)
# Out:
# int

# %%
saludo = "Hola"
nombre = "Miguel"

saludo + " " + nombre
# Out:
# 'Hola Miguel'

# %%
saludo = "Hola"
nombre = "Miguel"
edad = 37 # este valor es un entero, debe convertirse a string para poder concatenarse

saludo + " " + nombre + " tenes " + str(edad) + " años"
# Out:
# 'Hola Miguel tenes 37 años'

# %% [markdown]
# ## Concateno con "format"

# %%
frase = "Hola {}, tenes {} años".format(nombre, edad)

frase
# Out:
# 'Hola Miguel, tenes 37 años'

# %% [markdown]
# ## Concateno con "f-string"

# %%
frase_2 = f"Hola {nombre}, tenes {edad} años"

frase_2
# Out:
# 'Hola Miguel, tenes 37 años'
