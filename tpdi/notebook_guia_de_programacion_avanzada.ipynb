# %%
lista_pares = [(1,2), (3,4), (5,6)]

for a, b in lista_pares:
    print(a,b)
# Out:
# 1 2
# 3 4
# 5 6

# %%
import time

time.time()
# Out:
# 1755273839.4702556

# %%
from time import ctime

ctime(1499517005.3954754)
# Out:
# 'Sat Jul  8 09:30:05 2017'

# %%
help(time.ctime)
# Out:
# Help on built-in function ctime in module time:
#
# ctime(...)
#     ctime(seconds) -> string
#
#     Convert a time in seconds since the Epoch to a string in local time.
#     This is equivalent to asctime(localtime(seconds)). When the time tuple is
#     not present, current time as returned by localtime() is used.

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\marti\\AppData\\Roaming\\Python\\Python312\\site-packages', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\marti\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\Pythonwin']

# %%
divmod(5,2)
# Out:
# (2, 1)

# %%
t = "Hola Mundo"

t[::-1]
# Out:
# 'odnuM aloH'

# %%
cuadrados = [x ** 2 for x in range(5)]
cuadrados
# Out:
# [0, 1, 4, 9, 16]

# %%
a = 5
b = 3
a & b
# Out:
# 1
