# %%
import pandas as pd

'''
Consigna:

1) Marco Teórico: De la página equijar recopilar información de interés del TOP 10 de los jinetes entre los años 2019 al 2024. Ejemplo: Jinete, cantidad de carrera que participó, victorias obtenidas, nacionalidad, caballo utilizado, peso del jinete, entre otros.

2) De la información recopilada en el punto anterior deberá:

a. Plantear una hipótesis simple entre los jinetes y las victorias que pueda ser analizada con los datos anteriores para aceptar o rechazar la misma.

b. Analizar y buscar una relación entre los datos (puede elegir uno o más), presentar los datos y describir la información presentada.
'''


# Ejercicio 1) Datos en formato de lista de diccionarios
data_2024 = [
    {"Pos": 1, "Nombre": "V.Janacek", "Carreras": 270, "Victorias": "52 (19.26%)", "Segundos": "41 (15.19%)", "Terceros": "42 (15.56%)", "Cuartos": "35 (12.96%)", "Euros": 697510},
    {"Pos": 2, "Nombre": "R.Sousa", "Carreras": 260, "Victorias": "49 (18.85%)", "Segundos": "59 (22.69%)", "Terceros": "48 (18.46%)", "Cuartos": "25 (9.62%)", "Euros": 626150},
    {"Pos": 3, "Nombre": "J.Gelabert", "Carreras": 251, "Victorias": "38 (15.14%)", "Segundos": "38 (15.14%)", "Terceros": "33 (13.15%)", "Cuartos": "27 (10.76%)", "Euros": 448540},
    {"Pos": 4, "Nombre": "R.N.Valle", "Carreras": 205, "Victorias": "33 (16.10%)", "Segundos": "35 (17.07%)", "Terceros": "30 (14.63%)", "Cuartos": "35 (17.07%)", "Euros": 510300},
    {"Pos": 5, "Nombre": "N.de Julián", "Carreras": 190, "Victorias": "24 (12.63%)", "Segundos": "17 (8.95%)", "Terceros": "15 (7.89%)", "Cuartos": "28 (14.74%)", "Euros": 231100},
    {"Pos": 6, "Nombre": "D.Sikorova", "Carreras": 182, "Victorias": "22 (12.09%)", "Segundos": "25 (13.74%)", "Terceros": "30 (16.48%)", "Cuartos": "25 (13.74%)", "Euros": 245450},
    {"Pos": 7, "Nombre": "B.Fayos", "Carreras": 147, "Victorias": "19 (12.93%)", "Segundos": "15 (10.20%)", "Terceros": "19 (12.93%)", "Cuartos": "20 (13.61%)", "Euros": 222400},
    {"Pos": 8, "Nombre": "C.Pérez", "Carreras": 128, "Victorias": "15 (11.72%)", "Segundos": "14 (10.94%)", "Terceros": "10 (7.81%)", "Cuartos": "18 (14.06%)", "Euros": 120400},
    {"Pos": 9, "Nombre": "Srta.Relaño R", "Carreras": 20, "Victorias": "10 (50.00%)", "Segundos": "3 (15.00%)", "Terceros": "2 (10.00%)", "Cuartos": "2 (10.00%)", "Euros": 51700},
    {"Pos": 10, "Nombre": "R.Ramos", "Carreras": 89, "Victorias": "8 (8.99%)", "Segundos": "7 (7.87%)", "Terceros": "13 (14.61%)", "Cuartos": "6 (6.74%)", "Euros": 103100}
]

data_2023 = [
    {"Pos": 1, "Nombre": "V.Janacek", "Carreras": 292, "Victorias": "82 (28.08%)", "Segundos": "56 (19.18%)", "Terceros": "44 (15.07%)", "Cuartos": "34 (11.64%)", "Euros": 1001570},
    {"Pos": 2, "Nombre": "R.Sousa", "Carreras": 251, "Victorias": "61 (24.30%)", "Segundos": "47 (18.73%)", "Terceros": "39 (15.54%)", "Cuartos": "30 (11.95%)", "Euros": 680900},
    {"Pos": 3, "Nombre": "J.Gelabert", "Carreras": 302, "Victorias": "38 (12.58%)", "Segundos": "64 (21.19%)", "Terceros": "42 (13.91%)", "Cuartos": "39 (12.91%)", "Euros": 669160},
    {"Pos": 4, "Nombre": "D.Sikorova", "Carreras": 206, "Victorias": "31 (15.05%)", "Segundos": "30 (14.56%)", "Terceros": "20 (9.71%)", "Cuartos": "22 (10.68%)", "Euros": 261160},
    {"Pos": 5, "Nombre": "R.N.Valle", "Carreras": 195, "Victorias": "31 (15.90%)", "Segundos": "24 (12.31%)", "Terceros": "34 (17.44%)", "Cuartos": "24 (12.31%)", "Euros": 407460},
    {"Pos": 6, "Nombre": "B.Fayos", "Carreras": 161, "Victorias": "24 (14.91%)", "Segundos": "21 (13.04%)", "Terceros": "30 (18.63%)", "Cuartos": "19 (11.80%)", "Euros": 282600},
    {"Pos": 7, "Nombre": "N.de Julián", "Carreras": 198, "Victorias": "18 (9.09%)", "Segundos": "27 (13.64%)", "Terceros": "25 (12.63%)", "Cuartos": "17 (8.59%)", "Euros": 232630},
    {"Pos": 8, "Nombre": "C.Pérez", "Carreras": 189, "Victorias": "14 (7.41%)", "Segundos": "12 (6.35%)", "Terceros": "23 (12.17%)", "Cuartos": "26 (13.76%)", "Euros": 140375},
    {"Pos": 9, "Nombre": "M.E.Fernández", "Carreras": 116, "Victorias": "10 (8.62%)", "Segundos": "9 (7.76%)", "Terceros": "11 (9.48%)", "Cuartos": "12 (10.34%)", "Euros": 144200},
    {"Pos": 10, "Nombre": "A.Gutiérrez Val", "Carreras": 66, "Victorias": "10 (15.15%)", "Segundos": "7 (10.61%)", "Terceros": "10 (15.15%)", "Cuartos": "5 (7.58%)", "Euros": 198000}
]

data_2022 = [
    {"Pos": 1, "Nombre": "V.Janacek", "Carreras": 308, "Victorias": "69 (22.40%)", "Segundos": "48 (15.58%)", "Terceros": "50 (16.23%)", "Cuartos": "38 (12.34%)", "Euros": 801940},
    {"Pos": 2, "Nombre": "R.Sousa", "Carreras": 204, "Victorias": "57 (27.94%)", "Segundos": "37 (18.14%)", "Terceros": "34 (16.67%)", "Cuartos": "23 (11.27%)", "Euros": 722544},
    {"Pos": 3, "Nombre": "B.Fayos", "Carreras": 278, "Victorias": "45 (16.19%)", "Segundos": "55 (19.78%)", "Terceros": "36 (12.95%)", "Cuartos": "43 (15.47%)", "Euros": 605350},
    {"Pos": 4, "Nombre": "J.Zambudio", "Carreras": 237, "Victorias": "33 (13.92%)", "Segundos": "31 (13.08%)", "Terceros": "34 (14.35%)", "Cuartos": "28 (11.81%)", "Euros": 344850},
    {"Pos": 5, "Nombre": "J.Gelabert", "Carreras": 278, "Victorias": "24 (8.63%)", "Segundos": "48 (17.27%)", "Terceros": "45 (16.19%)", "Cuartos": "34 (12.23%)", "Euros": 411500},
    {"Pos": 6, "Nombre": "V. Alonso V", "Carreras": 164, "Victorias": "22 (13.41%)", "Segundos": "14 (8.54%)", "Terceros": "18 (10.98%)", "Cuartos": "13 (7.93%)", "Euros": 149025},
    {"Pos": 7, "Nombre": "R.N.Valle", "Carreras": 152, "Victorias": "21 (13.82%)", "Segundos": "14 (9.21%)", "Terceros": "16 (10.53%)", "Cuartos": "17 (11.18%)", "Euros": 181600},
    {"Pos": 8, "Nombre": "J.L.Martínez", "Carreras": 106, "Victorias": "21 (19.81%)", "Segundos": "14 (13.21%)", "Terceros": "12 (11.32%)", "Cuartos": "12 (11.32%)", "Euros": 296800},
    {"Pos": 9, "Nombre": "R.Ramos", "Carreras": 131, "Victorias": "21 (16.03%)", "Segundos": "13 (9.92%)", "Terceros": "10 (7.63%)", "Cuartos": "20 (15.27%)", "Euros": 159099},
    {"Pos": 10, "Nombre": "C.Pérez", "Carreras": 179, "Victorias": "18 (10.06%)", "Segundos": "24 (13.41%)", "Terceros": "19 (10.61%)", "Cuartos": "13 (7.26%)", "Euros": 169350}
]

data_2021 = [
    {"Pos": 1, "Nombre": "R.Sousa", "Carreras": 290, "Victorias": "57 (19.66%)", "Segundos": "34 (11.72%)", "Terceros": "54 (18.62%)", "Cuartos": "30 (10.34%)", "Euros": 606660},
    {"Pos": 2, "Nombre": "V.Janacek", "Carreras": 262, "Victorias": "46 (17.56%)", "Segundos": "38 (14.50%)", "Terceros": "44 (16.79%)", "Cuartos": "32 (12.21%)", "Euros": 537650},
    {"Pos": 3, "Nombre": "B.Fayos", "Carreras": 231, "Victorias": "43 (18.61%)", "Segundos": "46 (19.91%)", "Terceros": "32 (13.85%)", "Cuartos": "38 (16.45%)", "Euros": 559250},
    {"Pos": 4, "Nombre": "J.Gelabert", "Carreras": 244, "Victorias": "37 (15.16%)", "Segundos": "40 (16.39%)", "Terceros": "23 (9.43%)", "Cuartos": "31 (12.70%)", "Euros": 348650},
    {"Pos": 5, "Nombre": "J.L.Martínez", "Carreras": 149, "Victorias": "28 (18.79%)", "Segundos": "11 (7.38%)", "Terceros": "26 (17.45%)", "Cuartos": "14 (9.40%)", "Euros": 363800},
    {"Pos": 6, "Nombre": "V. Alonso V", "Carreras": 100, "Victorias": "23 (23.00%)", "Segundos": "15 (15.00%)", "Terceros": "6 (6.00%)", "Cuartos": "15 (15.00%)", "Euros": 157580},
    {"Pos": 7, "Nombre": "M.E.Fernández", "Carreras": 150, "Victorias": "20 (13.33%)", "Segundos": "21 (14.00%)", "Terceros": "20 (13.33%)", "Cuartos": "21 (14.00%)", "Euros": 214000},
    {"Pos": 8, "Nombre": "J.Zambudio", "Carreras": 121, "Victorias": "16 (13.22%)", "Segundos": "15 (12.40%)", "Terceros": "16 (13.22%)", "Cuartos": "15 (12.40%)", "Euros": 107000},
    {"Pos": 9, "Nombre": "R.Ramos", "Carreras": 167, "Victorias": "15 (8.98%)", "Segundos": "14 (8.38%)", "Terceros": "22 (13.17%)", "Cuartos": "19 (11.38%)", "Euros": 214880},
    {"Pos": 10, "Nombre": "J.L.Borrego", "Carreras": 115, "Victorias": "15 (13.04%)", "Segundos": "9 (7.83%)", "Terceros": "11 (9.57%)", "Cuartos": "12 (10.43%)", "Euros": 156000}
]

data_2020 = [
    {"Pos": 1, "Nombre": "V.Janacek", "Carreras": 272, "Victorias": "53 (19.49%)", "Segundos": "41 (15.07%)", "Terceros": "46 (16.91%)", "Cuartos": "30 (11.03%)", "Euros": 548405},
    {"Pos": 2, "Nombre": "R.Sousa", "Carreras": 244, "Victorias": "47 (19.26%)", "Segundos": "29 (11.89%)", "Terceros": "32 (13.11%)", "Cuartos": "39 (15.98%)", "Euros": 479330},
    {"Pos": 3, "Nombre": "B.Fayos", "Carreras": 224, "Victorias": "40 (17.86%)", "Segundos": "37 (16.52%)", "Terceros": "25 (11.16%)", "Cuartos": "25 (11.16%)", "Euros": 339580},
    {"Pos": 4, "Nombre": "I.Melgarejo", "Carreras": 212, "Victorias": "29 (13.68%)", "Segundos": "28 (13.21%)", "Terceros": "25 (11.79%)", "Cuartos": "27 (12.74%)", "Euros": 271500},
    {"Pos": 5, "Nombre": "J.Gelabert", "Carreras": 237, "Victorias": "23 (9.70%)", "Segundos": "22 (9.28%)", "Terceros": "29 (12.24%)", "Cuartos": "33 (13.92%)", "Euros": 249925},
    {"Pos": 6, "Nombre": "J.L.Martínez", "Carreras": 148, "Victorias": "22 (14.86%)", "Segundos": "24 (16.22%)", "Terceros": "15 (10.14%)", "Cuartos": "16 (10.81%)", "Euros": 305040},
    {"Pos": 7, "Nombre": "M.E.Fernández", "Carreras": 100, "Victorias": "15 (15.00%)", "Segundos": "14 (14.00%)", "Terceros": "11 (11.00%)", "Cuartos": "9 (9.00%)", "Euros": 128950},
    {"Pos": 8, "Nombre": "V.M.Valenzuela", "Carreras": 139, "Victorias": "14 (10.07%)", "Segundos": "11 (7.91%)", "Terceros": "14 (10.07%)", "Cuartos": "9 (6.47%)", "Euros": 97000},
    {"Pos": 9, "Nombre": "J.Grosjean", "Carreras": 79, "Victorias": "12 (15.19%)", "Segundos": "10 (12.66%)", "Terceros": "16 (20.25%)", "Cuartos": "9 (11.39%)", "Euros": 190260},
    {"Pos": 10, "Nombre": "N.de Julián", "Carreras": 172, "Victorias": "10 (5.81%)", "Segundos": "15 (8.72%)", "Terceros": "14 (8.14%)", "Cuartos": "18 (10.47%)", "Euros": 126650}
]

data_2019 = [
    {"Pos": 1, "Nombre": "V.Janacek", "Carreras": 351, "Victorias": "68 (19.37%)", "Segundos": "63 (17.95%)", "Terceros": "59 (16.81%)", "Cuartos": "49 (13.96%)", "Euros": 762810},
    {"Pos": 2, "Nombre": "R.Sousa", "Carreras": 324, "Victorias": "66 (20.37%)", "Segundos": "53 (16.36%)", "Terceros": "41 (12.65%)", "Cuartos": "48 (14.81%)", "Euros": 694070},
    {"Pos": 3, "Nombre": "B.Fayos", "Carreras": 315, "Victorias": "57 (18.10%)", "Segundos": "54 (17.14%)", "Terceros": "36 (11.43%)", "Cuartos": "33 (10.48%)", "Euros": 740900},
    {"Pos": 4, "Nombre": "J.Gelabert", "Carreras": 325, "Victorias": "41 (12.62%)", "Segundos": "31 (9.54%)", "Terceros": "42 (12.92%)", "Cuartos": "40 (12.31%)", "Euros": 523325},
    {"Pos": 5, "Nombre": "J.L.Martínez", "Carreras": 156, "Victorias": "26 (16.67%)", "Segundos": "26 (16.67%)", "Terceros": "23 (14.74%)", "Cuartos": "17 (10.90%)", "Euros": 428225},
    {"Pos": 6, "Nombre": "R.N.Valle", "Carreras": 151, "Victorias": "15 (9.93%)", "Segundos": "17 (11.26%)", "Terceros": "16 (10.60%)", "Cuartos": "13 (8.61%)", "Euros": 192210},
    {"Pos": 7, "Nombre": "F.Jiménez A.", "Carreras": 172, "Victorias": "14 (8.14%)", "Segundos": "14 (8.14%)", "Terceros": "20 (11.63%)", "Cuartos": "26 (15.12%)", "Euros": 156650},
    {"Pos": 8, "Nombre": "J.L.Borrego", "Carreras": 128, "Victorias": "13 (10.16%)", "Segundos": "14 (10.94%)", "Terceros": "9 (7.03%)", "Cuartos": "11 (8.59%)", "Euros": 177900},
    {"Pos": 9, "Nombre": "V.M.Valenzuela", "Carreras": 150, "Victorias": "12 (8.00%)", "Segundos": "11 (7.33%)", "Terceros": "14 (9.33%)", "Cuartos": "11 (7.33%)", "Euros": 125450},
    {"Pos": 10, "Nombre": "I.Melgarejo", "Carreras": 137, "Victorias": "10 (7.30%)", "Segundos": "22 (16.06%)", "Terceros": "19 (13.87%)", "Cuartos": "16 (11.68%)", "Euros": 135650}]


data_2024 = pd.DataFrame(data_2024)
data_2023 = pd.DataFrame(data_2023)
data_2022 = pd.DataFrame(data_2022)
data_2021 = pd.DataFrame(data_2021)
data_2020 = pd.DataFrame(data_2020)
data_2019 = pd.DataFrame(data_2019)

print(data_2024)
print(data_2023)
print(data_2022)
print(data_2021)
print(data_2020)
print(data_2019)
# Out:
#    Pos         Nombre  Carreras    Victorias     Segundos     Terceros  \
# 0    1      V.Janacek       270  52 (19.26%)  41 (15.19%)  42 (15.56%)
# 1    2        R.Sousa       260  49 (18.85%)  59 (22.69%)  48 (18.46%)
# 2    3     J.Gelabert       251  38 (15.14%)  38 (15.14%)  33 (13.15%)
# 3    4      R.N.Valle       205  33 (16.10%)  35 (17.07%)  30 (14.63%)
# 4    5    N.de Julián       190  24 (12.63%)   17 (8.95%)   15 (7.89%)
# 5    6     D.Sikorova       182  22 (12.09%)  25 (13.74%)  30 (16.48%)
# 6    7        B.Fayos       147  19 (12.93%)  15 (10.20%)  19 (12.93%)
# 7    8        C.Pérez       128  15 (11.72%)  14 (10.94%)   10 (7.81%)
# 8    9  Srta.Relaño R        20  10 (50.00%)   3 (15.00%)   2 (10.00%)
# 9   10        R.Ramos        89    8 (8.99%)    7 (7.87%)  13 (14.61%)
#
#        Cuartos   Euros
# 0  35 (12.96%)  697510
# 1   25 (9.62%)  626150
# 2  27 (10.76%)  448540
# 3  35 (17.07%)  510300
# 4  28 (14.74%)  231100
# 5  25 (13.74%)  245450
# ...

# %%
# Creamos una lista con todos los jinetes que aparecen al menos una vez en al menos uno de los dfs

jinetes = []

for year in range(2019, 2025):
    data = globals().get(f"data_{year}")  # Obtén el DataFrame correspondiente
    for i in range(len(data)):  # Itera sobre las filas del DataFrame
        nombre = data.iloc[i].get("Nombre")  # Accede al valor de la columna "Nombre"
        if pd.notna(nombre) and nombre not in jinetes:  # Verifica si no es NaN
            jinetes.append(nombre)

print(jinetes)
print(f"La cantidad de jinetes en el top al menos en uno de los años analizados es: {len(jinetes)}")
# Out:
# ['V.Janacek', 'R.Sousa', 'B.Fayos', 'J.Gelabert', 'J.L.Martínez', 'R.N.Valle', 'F.Jiménez A.', 'J.L.Borrego', 'V.M.Valenzuela', 'I.Melgarejo', 'M.E.Fernández', 'J.Grosjean', 'N.de Julián', 'V. Alonso V', 'J.Zambudio', 'R.Ramos', 'C.Pérez', 'D.Sikorova', 'A.Gutiérrez Val', 'Srta.Relaño R']
# La cantidad de jinetes en el top al menos en uno de los años analizados es: 20

# %%
# Cargar datos en DataFrames
dataframes = [
    data_2019, data_2020, data_2021, data_2022, data_2023, data_2024
]

# Limpiar y separar victorias y porcentaje
for df in dataframes:
    df[['Victorias_Num', 'Victorias_Pct']] = df['Victorias'].str.extract(r'(\d+)\s\(([\d.]+)%\)').astype(float)

# Concatenar todos los DataFrames
df_combined = pd.concat(dataframes)

# Calcular totales y promedios por jinete
stats = df_combined.groupby('Nombre').agg(
    Total_Victorias=('Victorias_Num', 'sum'),
    Total_Carreras=('Carreras', 'sum'),
    Promedio_Pct_Victorias=('Victorias_Pct', 'mean'),
    Promedio_Euros = ('Euros', 'mean')
).reset_index()

# Ordenar por Total de Victorias
df_ordenado_victorias = stats.sort_values(by='Total_Victorias', ascending=False)

# Ordenar por Promedio de Porcentaje de Victorias
df_ordenado_pct = stats.sort_values(by='Promedio_Pct_Victorias', ascending=False)

# Mostrar resultados
print("Ordenado por Total de Victorias:")
print(df_ordenado_victorias)

print("\nOrdenado por Promedio de Porcentaje de Victorias:")
print(df_ordenado_pct)
# Out:
# Ordenado por Total de Victorias:
#              Nombre  Total_Victorias  Total_Carreras  Promedio_Pct_Victorias  \
# 18        V.Janacek            370.0            1755               21.026667
# 15          R.Sousa            337.0            1573               21.730000
# 1           B.Fayos            228.0            1356               16.433333
# 6        J.Gelabert            201.0            1637               12.305000
# 13        R.N.Valle            100.0             703               13.937500
# 9      J.L.Martínez             97.0             559               17.532500
# 3        D.Sikorova             53.0             388               13.570000
# 12      N.de Julián             52.0             560                9.176667
# 10       J.Zambudio             49.0             358               13.570000
# 2           C.Pérez             47.0             496                9.730000
# 17      V. Alonso V             45.0             264               18.205000
# ...

# %% [markdown]
# Ejercicio 2 a) Hipótesis: Hay una diferencia estadísticamente significativa en el porcentaje de carreras ganadas de la Srta.Relaño R. respecto del resto de jinetes.
#
# Ejercicio 2 b) Para buscar una relación lineal entre dos de las variables que tenemos vamos a hacer una matriz de correlación con el Coeficiente de Correlación de Pearson.

# %%
# Reiniciar los índices y eliminar la columna 'Nombre'
stats_sin_nombre = stats.drop(columns=['Nombre']).reset_index(drop=True)

# Calcular la matriz de correlación
matriz_correlacion = stats_sin_nombre.corr(method='pearson')

import seaborn as sns

# Configurar el tamaño del gráfico
plt.figure(figsize=(10, 8))

# Crear el mapa de calor
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt='.2f', square=True)

# Mostrar el gráfico
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Como se puede observar hay una relación líneal positiva muy fuerte entre las variables Total_Victorias y Promedio_Euros
